# %%
import numpy as np
from main import puntos_lagrange, newton_raphson, l1, rp, equipotenciales

# %% [markdown]
# Primer sistema de coordenadas (Centro de masas en el origen)

# %% [markdown]
# Para una estrella binaria con M1=0.85 MS, M2= 0.17 MS y a=0.718 RS

# %%
puntos_lagrange(0.85, 0.17, 0.718)
# Out:
# Para los tres primeros Puntos de Lagrange r=(x,0), estan contenidos en las siguientes superficies equipotenciales:
# Punto r=  -1.0691069106910691
# V= -1.5825237501175484
# Punto r=  0.49224922492249223
# V= -1.8744963296325883
# Punto r=  1.2715271527152716
# V= -1.7681703243004414

# %% [markdown]
# Segundo sistema de coordenadas (Estrella 1 en el origen)

# %% [markdown]
# Primer punto de Lagrange L1 para sistema de diferente q= M2/M1

# %%
q=0.1
while q<1:
    print(f"Para q= {q}, Raíz encontrada: {l1(q)}")
    q=q+0.1
    q=np.round(q,1)
# Out:
# Para q= 0.1, Raíz encontrada: 0.7175125871145084
# Para q= 0.2, Raíz encontrada: 0.6585556789540677
# Para q= 0.3, Raíz encontrada: 0.6208667167280795
# Para q= 0.4, Raíz encontrada: 0.592947511902421
# Para q= 0.5, Raíz encontrada: 0.5707515715233058
# Para q= 0.6, Raíz encontrada: 0.5523426295075485
# Para q= 0.7, Raíz encontrada: 0.5366337261794368
# Para q= 0.8, Raíz encontrada: 0.5229503371552613
# Para q= 0.9, Raíz encontrada: 0.5108437938638397

# %% [markdown]
# Curvas equipotenciales y sus respectivos radios polares para un sistema de q=0.5

# %%
equipotenciales(0.5)
# Out:
# Para q= 0.5 y potencial= 2.660156284730476, Radio polar: 0.4535551924944939
# Para q= 0.5 y potencial= 2.7320524005340023, Radio polar: 0.43968757489098936
# Para q= 0.5 y potencial= 2.875844632141055, Radio polar: 0.41426508883481433
# Para q= 0.5 y potencial= 5.75168926428211, Radio polar: 0.19009651399489846
# Para q= 0.5 y potencial= 8.627533896423165, Radio polar: 0.12298197825608267
